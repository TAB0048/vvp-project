# %%
from maze import Maze, MazeTemplate

# %% [markdown]
# Example of initializing maze object, loading data from CSV file and creating a picture of the maze (without any path).

# %%
maze1 = Maze()
maze1.load_maze_csv("./data/maze_1.csv")
maze1.draw_maze()

# %%
maze1 = Maze()
maze1.load_maze_csv("./data/maze_2.csv")
maze1.draw_maze()

# %%
maze1 = Maze()
maze1.load_maze_csv("./data/maze_3.csv")
maze1.draw_maze()

# %%
maze1 = Maze()
maze1.load_maze_csv("./data/maze_4.csv")
maze1.draw_maze()

# %%
maze1 = Maze()
maze1.load_maze_csv("./data/maze_5.csv")
maze1.draw_maze()
